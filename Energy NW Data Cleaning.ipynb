# %% [markdown]
# # Energy NW Text Cleaning

# %% [markdown]
# ### The goal of this notebook is to clean the Energy NW text data within the CONCAT_TEXT_FOR_WKS column. The aim is to consistently clean the data. The cleaned up dataframe will be published on Github.

# %% [markdown]
# #### Import necessary libraries/tools

# %%
#!pip install spacy
#!pip install gensim
#!pip install spacy && python3 -m spacy download en

# %%
import nltk
import spacy
import unicodedata
import re
import nltk
from nltk.corpus import wordnet
import numpy as np
import pandas as pd
import collections
import text_normalizer as tn
#from textblob import Word
from nltk.tokenize.toktok import ToktokTokenizer
from bs4 import BeautifulSoup
import en_core_web_sm
import time

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/Jewel.Matsch-
# [nltk_data]     Rowekamp@ibm.com/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Load the Dataset

# %%
raw_df = pd.read_csv('Full_Clean.csv')
raw_df.head(10)
# Out:
#    AR_NUMBER AR_OWED_TO_GRP AR_TYPE  ORIGINATION_DATE AR_PRIORITY AR_SEVERITY  \
# 0     383472     AR-OPSWM        CR          20180815         CAQ           C
# 1     383473     CR-TRNDREP      CR          20180815         CAQ           D
# 2     383474     CR-TRNDREP      CR          20180815         CAQ           D
# 3     383476     CR-TRNDREP      CR          20180815        NCAQ           4
# 4     383477     CR-CRG          CR          20180815         CAQ           D
# 5     383478     CR-TRNDREP      CR          20180815         CAQ           D
# 6     383479     AR-OPSCM        CR          20180815        NCAQ           3
# 7     383490     CR-TRNDREP      CR          20180815         CAQ           D
# 8     383491     AR-OPSMGT       CR          20180815         CAQ           C
# 9     383497     ITMGMT          CR          20180815        NCAQ           3
#
#                                           AR_SUBJECT  WORK_REQ_QTY TSSSC  \
# 0             RCIC and HPCS Low CST level Swap-over.           2.0     Y
# 1                     RCIC-P-3 will not start in RUN           1.0     Y
# 2  H13-P601 A1 drop 5-6 HPCS-SUCTION SWITCHOVER a...           1.0     Y
# 3                                        BRE 36 & 37           1.0     N
# 4      Received the ROD DRIVE CONTROL SYS INOP alarm           NaN     Y
# 5            HPCS SUCTION SWITCHOVER ALARM LOCKED IN           4.0     Y
# 6                   CW-CT-1A Approx 1" from overflow           NaN     N
# 7                  Security CCTV33 needs maintenance           1.0     N
# 8  SW-V-16A and 22A changed to LO without 50.59 s...           NaN     Y
# 9                 EP Copiers unable to Scan to Email           NaN   NaN
#
#   NON_TSSSC  DNC COMP_MEASURE QUALITY EQUIP_REL  \
# 0         Y    Y          NaN       N       YES
# 1         Y    Y          NaN       N       YES
# 2         Y    Y          NaN       N       YES
# 3         N  NaN          NaN       N       YES
# 4         Y    Y          NaN       N       YES
# 5         N    Y          NaN       N       YES
# 6         N    N          NaN       N        NO
# 7         N  NaN          NaN       N       YES
# 8         N    Y          NaN       N       YES
# 9       NaN  NaN          NaN       N        NO
#
#                                    DESCRIPTION_NOTES  \
# 0  <D> **** Detailed Description **** During fill...
# 1  <C> Item is a CRBB for Maintenance to gather a...
# 2  <D> **** Detailed Description **** H13-P601 A1...
# 3  <D> **** Detailed Description **** Both Bre's ...
# 4  <D> **** Detailed Description **** Received th...
# 5  <D> **** Detailed Description **** During fill...
# 6  <D> **** Detailed Description **** During oper...
# 7  <D> **** Detailed Description **** Security CC...
# 8  <C> Reviewed ANON CR for content per SWP-CAP-0...
# 9  <D> **** Detailed Description **** New Canon C...
#
#                                               AR_EPN PRIORITY_SEVERITY  \
# 0                 02-00-HPCS-LS-1A,02-00-RCIC-LS-15A             CAQ:C
# 1                                     02-00-RCIC-P-3             CAQ:D
# 2                                   02-00-HPCS-LS-1A             CAQ:D
# 3                                                NaN            NCAQ:4
# 4                                                NaN             CAQ:D
# 5  02-00-HPCS-LS-1A,02-00-HPCS-LS-1B,02-00-HPCS-P...             CAQ:D
# 6                                                NaN            NCAQ:3
# 7                                  02-00-SEC-CCTV-33             CAQ:D
# 8                      02-00-SW-V-16A,02-00-SW-V-22A             CAQ:C
# 9                                                NaN            NCAQ:3
#
#                                  CONCAT_TEXT_FOR_WKS
# 0  RCIC and HPCS Low CST level Swap-over.:   Duri...
# 1  RCIC-P-3 will not start in RUN:   SOP-RCIC-FIL...
# 2  H13-P601 A1 drop 5-6 HPCS-SUCTION SWITCHOVER a...
# 3  BRE 36 & 37:   Both Bre's need to have their w...
# 4  Received the ROD DRIVE CONTROL SYS INOP alarm:...
# 5  HPCS SUCTION SWITCHOVER ALARM LOCKED IN:   Dur...
# 6  CW-CT-1A Approx 1" from overflow:   During ope...
# 7  Security CCTV33 needs maintenance:   Security ...
# 8  SW-V-16A and 22A changed to LO without 50.59 s...
# 9  EP Copiers unable to Scan to Email:   New Cano...

# %%
raw_df.columns
# Out:
# Index(['AR_NUMBER', 'AR_OWED_TO_GRP', 'AR_TYPE', 'ORIGINATION_DATE',
#        'AR_PRIORITY', 'AR_SEVERITY', 'AR_SUBJECT', 'WORK_REQ_QTY', 'TSSSC',
#        'NON_TSSSC', 'DNC', 'COMP_MEASURE', 'QUALITY', 'EQUIP_REL',
#        'DESCRIPTION_NOTES', 'AR_EPN', 'PRIORITY_SEVERITY',
#        'CONCAT_TEXT_FOR_WKS'],
#       dtype='object')

# %%
raw_df.shape
# Out:
# (11337, 18)

# %% [markdown]
# #### Select AR_NUMBER and Text Column

# %%
data_selection = raw_df.iloc[:,[0, 4, 5, 16, 17]]

# %%
data_selection.tail(5)
# Out:
#        AR_NUMBER AR_PRIORITY AR_SEVERITY PRIORITY_SEVERITY  \
# 11332     402851        NCAQ           4            NCAQ:4
# 11333     402858        NCAQ           4            NCAQ:4
# 11334     402859        NCAQ           4            NCAQ:4
# 11335     402860         CAQ           D             CAQ:D
# 11336     402861        NCAQ           3            NCAQ:3
#
#                                      CONCAT_TEXT_FOR_WKS
# 11332  p door b door latch sticking perform fire door...
# 11333  conference call drop weekend production call w...
# 11334  pwc p slow leak pump suction fit bermed area p...
# 11335  filter aa end roll alarm alarm p filter aa end...
# 11336  drum rw cause alara safety concern currently l...

# %% [markdown]
# ### Clean Text Column

# %%
#Tracking how long this step takes.
start = time.time()

#Using the stopwords list from the natural language toolkit in english, which was displayed earlier.
stopword_list = nltk.corpus.stopwords.words('english')

#Removing negation words from the stopwords list to maintain them in the corpus.
stopword_list.remove('no')
stopword_list.remove('not')

# Call the normalize corpus function on the Article column of the unprocessed DataFrame
norm_corpus = tn.normalize_corpus(corpus=data_selection['CONCAT_TEXT_FOR_WKS'], html_stripping=True, contraction_expansion=True, 
                                  accented_char_removal=True, text_lower_case=True, text_lemmatization=True, 
                                  text_stemming=True, special_char_removal=True, remove_digits=True,
                                  stopword_removal=True, stopwords=stopword_list)

#Add the new "Clean Article" column to the clean_data_df DataFrame
data_selection['CONCAT_TEXT_FOR_WKS'] = norm_corpus

#Calculate how much time this function took to work on the unprocessed dataframe.
end = time.time()
minutes = (end - start)/60

print('It took', minutes, ' minutes to clean the text data.')
# Out:
# It took 2.7521117170651754  minutes to clean the text data.
# /Users/Jewel.Matsch-Rowekamp@ibm.com/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Display Results of Cleaned Text Column

# %%
data_selection.tail(5)
# Out:
#        AR_NUMBER AR_PRIORITY AR_SEVERITY PRIORITY_SEVERITY  \
# 11332     402851        NCAQ           4            NCAQ:4
# 11333     402858        NCAQ           4            NCAQ:4
# 11334     402859        NCAQ           4            NCAQ:4
# 11335     402860         CAQ           D             CAQ:D
# 11336     402861        NCAQ           3            NCAQ:3
#
#                                      CONCAT_TEXT_FOR_WKS
# 11332  p door b door latch sticking perform fire door...
# 11333  conference call drop weekend production call w...
# 11334  pwc p slow leak pump suction fit bermed area p...
# 11335  filter aa end roll alarm alarm p filter aa end...
# 11336  drum rw cause alara safety concern currently l...

# %%
data_selection.shape
# Out:
# (11337, 5)

# %%
#Renaming for more descriptive name
energy_nw_clean_dataframe = data_selection

# %% [markdown]
# ### Save DataFrame

# %%
energy_nw_clean_dataframe
# Out:
#        AR_NUMBER AR_PRIORITY AR_SEVERITY PRIORITY_SEVERITY  \
# 0         383472         CAQ           C             CAQ:C
# 1         383473         CAQ           D             CAQ:D
# 2         383474         CAQ           D             CAQ:D
# 3         383476        NCAQ           4            NCAQ:4
# 4         383477         CAQ           D             CAQ:D
# ...          ...         ...         ...               ...
# 11332     402851        NCAQ           4            NCAQ:4
# 11333     402858        NCAQ           4            NCAQ:4
# 11334     402859        NCAQ           4            NCAQ:4
# 11335     402860         CAQ           D             CAQ:D
# 11336     402861        NCAQ           3            NCAQ:3
#
#                                      CONCAT_TEXT_FOR_WKS
# 0      rcic hpcs low cst level swap fill vent suction...
# 1      rcic p not start run sop rcic fill direct star...
# 2      hp drop hpcs suction switchover alarm hp drop ...
# 3                       bre bre need window evaluate bre
# 4      receive rod drive control sys inop alarm recei...
# ...                                                  ...
# 11332  p door b door latch sticking perform fire door...
# 11333  conference call drop weekend production call w...
# 11334  pwc p slow leak pump suction fit bermed area p...
# 11335  filter aa end roll alarm alarm p filter aa end...
# 11336  drum rw cause alara safety concern currently l...
#
# [11337 rows x 5 columns]

# %%
energy_nw_clean_dataframe.to_csv('energy_nw_clean_dataframe.csv', index=False)
